# %%
import random
import tkinter as tk
from tkinter import filedialog, Text
import os


#gui

def handler(event):
    text=entry.get()
    list1.append(text)
    list1.append("\n")
    changeText(listView,list1)
    entry.delete(0,tk.END)
    
def changeText(self,tex):
    self.configure(text=tex)
    
    

list1 = []

root = tk.Tk()
root.title('Task Selector')
        
root.bind("<Return>", handler)
canvas = tk.Canvas(root, height=700, width=700, bg="#809FFF")
canvas.pack()

#frame = tk.Frame(root, bg="#809FFF")
#frame.place(relwidth=0.9, relheight=0.9, relx=0.05, rely=0.05)

#inputItem = tk.Button(frame, text="Input item",bg='gray',fg='red')
#inputItem.pack()

#entry = tk.Entry(frame, bg='white')
#entry.pack()
    
label = tk.Label(canvas, text = "Write tasks you have to do. To stop input write 'stop'", bg='white')
label.place(relwidth=0.5, relheight=0.05, relx=0.25, rely=0.035)

listView = tk.Label(canvas, bg='white' )
listView.place(relwidth=0.7, relheight=0.7, relx=0.15, rely=0.15)

entry = tk.Entry(canvas, bg='white')
entry.place(relwidth=0.5, relheight=0.05, relx=0.25, rely=0.9)
    




root.mainloop()

#program

#lis = []
#print("Write tasks you have to do. To stop input write 'stop'")
#i=input()
#while i != 'stop':
#    lis.append(i)
#    i=input()
    
#print("The task you have to do is:")
#print(lis[random.randint(0,len(lis))])
